# %%
def intersection(lst1, lst2): 
    return list(set(lst1) & set(lst2))
# Driver Code 
lst1 = [15, 9, 10, 56, 23, 78, 5, 4, 9] 
lst2 = [9, 4, 5, 36, 47, 26, 10, 45, 87] 
print(intersection(lst1, lst2))
# Out:
# [9, 10, 4, 5]

# %%
from pymongo import MongoClient
client = MongoClient("mongodb://localhost:27017/basics")
if(client):
        print("connected")
db = client.Appcast
collections = db.JUNE5
count=0
lis1= []
for x in collections.find({}):
    lis1.append(x['Link'])
print(lis1)
lis2=['https://jobs.etalentnetwork.com/classification-comp-analyst/job/10906584']
print(set(lis1)&set(lis2))
print(set(lis1).isdisjoint(set(lis2)))
# Out:
# connected
# ['http://candidates.mdigroup.com/job/sr-software-engineer-software-development-fort-worth-texas-50255/2e035583-8704-11e9-ba5e-42010a8a0fca', 'http://candidates.mdigroup.com/job/digital-analyst-adobe-or-google-analytics-business-analysis-atlanta-georgia-50141/8f0cc544-7103-11e9-8331-42010a8a001f', 'http://candidates.mdigroup.com/job/sr-uiux-developer-software-development-fort-worth-texas-50254/2e03551b-8704-11e9-9a31-42010a8a0fc8', 'http://candidates.mdigroup.com/job/application-support-engineer-software-development-atlanta-georgia-50253/d29d0671-86fb-11e9-b3a8-42010a8a001f', 'http://candidates.mdigroup.com/job/japanese-bi-lingual-it-help-desk-support-dallas-infrastructure-support-plano-texas-50246/23966636-86c1-11e9-9a31-42010a8a0fc8', 'http://candidates.mdigroup.com/job/infosec3-incident-response-infrastructure-support-phoenix-arizona-50240/7eac5bf5-8619-11e9-9a31-42010a8a0fc8', 'http://candidates.mdigroup.com/job/senior-sql-developer-software-development-greenville-south-carolina-50238/2665c2d6-8611-11e9-ba5e-42010a8a0fca', 'http://candidates.mdigroup.com/job/program-manager-project-management-phoenix-arizona-50148/3f8e0dca-71ee-11e9-b2e6-42010a8a0fc6', 'http://candidates.mdigroup.com/job/bsa-2-business-analysis-phoenix-arizona-50229/bb19aa43-83f8-11e9-9a31-42010a8a0fc8', 'http://candidates.mdigroup.com/job/scrum-master-business-analysis-phoenix-arizona-49836/151d379f-4cf7-11e9-8579-42010a8a0030', 'http://candidates.mdigroup.com/job/portuguese-bi-lingual-it-help-desk-support-atl-infrastructure-support-norcross-georgia-50236/2e9478b1-83d7-11e9-b656-42010a8a0fc7', 'http://candidates.mdigroup.com/job/spanish-bi-lingual-it-help-desk-support-dallas-infrastructure-support-plano-texas